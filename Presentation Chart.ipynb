# %%
import pickle
import matplotlib.pyplot as plt

# %%
with open('data_set3.pickle','rb') as read_file:
    recipe_data = pickle.load(read_file)

recipe_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   4809 non-null   object
#  1   number_of_steps        4793 non-null   float64
#  2   number_of_ratings      4809 non-null   float64
#  3   rating_value           4143 non-null   float64
#  4   author                 4809 non-null   object
#  5   recipe_time            4748 non-null   object
#  6   number_of_ingredients  4809 non-null   int64
#  7   number_of_servings     4809 non-null   object
#  8   image_link             4809 non-null   object
#  9   recipe_link            4809 non-null   object
#  10  recipe_start_date      4724 non-null   datetime64[ns]
#  11  name_other             4809 non-null   object
#  12  recipe_categories      4809 non-null   object
#  13  main_course            4809 non-null   bool
#  14  dinner                 4809 non-null   bool
#  15  side_dish              4809 non-null   bool
#  16  easy                   4809 non-null   bool
#  17  dessert                4809 non-null   bool
#  18  quick                  4809 non-null   bool
#  19  weekday                4809 non-null   bool
#  20  appetizer              4809 non-null   bool
#  21  lunch                  4809 non-null   bool
#  22  recipe_keywords        4809 non-null   object
#  23  vegetarian             4809 non-null   bool
#  24  fall                   4809 non-null   bool
#  25  winter                 4809 non-null   bool
#  26  summer                 4809 non-null   bool
#  27  days_ago               4724 non-null   float64
#  28  recipe_time_in_min     4802 non-null   float64
# dtypes: bool(13), datetime64[ns](1), float64(5), int64(1), object(9)
# memory usage: 662.3+ KB

# %%
fig = plt.figure(figsize=(8,5))
plt.plot(recipe_data['recipe_start_date'], recipe_data['number_of_ratings'], "o",
           markerfacecolor = "#ea6b58", markeredgecolor="#2b2b30", markersize=10)
#plt.title('Number of Ratings by Estimated Publish Date', fontsize = 20)
plt.xlabel('Estimated Recipe Publish Date', fontsize=14)
plt.ylabel('Number of Ratings', fontsize=14)
plt.show();

fig.savefig('test.png')

# %%
recipe_data['number_of_ratings'].describe()
# Out:
# count     4809.000000
# mean       395.163859
# std        833.803002
# min          0.000000
# 25%         15.000000
# 50%        103.000000
# 75%        402.000000
# max      13705.000000
# Name: number_of_ratings, dtype: float64

# %%
recipe_data_condensed = recipe_data[['name','number_of_ratings', 'rating_value', 'author', 'recipe_start_date']]

# %%
recipe_data_condensed.sort_values(by='number_of_ratings', ascending = False).head(10)
# Out:
#                                              name  number_of_ratings  \
# 2918                               No-Knead Bread            13705.0
# 3860                      Old-Fashioned Beef Stew            10920.0
# 847                    Creamy Macaroni and Cheese            10852.0
# 713              Marcella Hazan’s Bolognese Sauce            10474.0
# 2403                    Caramelized Shallot Pasta             9910.0
# 1154                Oven-Roasted Chicken Shawarma             9448.0
# 844                        Chocolate Chip Cookies             8506.0
# 1204                    Roasted Chicken Provençal             8173.0
# 2291  Vinegar Chicken With Crushed Olive Dressing             7576.0
# 1770    Salted Chocolate Chunk Shortbread Cookies             7475.0
#
#       rating_value              author recipe_start_date
# 2918           5.0        Mark Bittman        2015-02-23
# 3860           5.0       Molly O'Neill        2014-12-08
# 847            5.0        Julia Moskin        2014-09-28
# 713            5.0  The New York Times        2015-05-31
# 2403           5.0        Alison Roman        2020-02-02
# 1154           5.0          Sam Sifton        2015-01-31
# 844            5.0         David Leite        2014-09-28
# 1204           5.0          Sam Sifton        2015-04-04
# 2291           4.0        Alison Roman        2019-09-30
# 1770           5.0        Alison Roman        2018-01-14
