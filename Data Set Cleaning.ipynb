# %%
import pickle 
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date

# %%
with open('html_data5.pickle','rb') as read_file:
    recipe_dictionary = pickle.load(read_file)

# %%
recipe_data = pd.DataFrame(recipe_dictionary, 
                columns =['name', 'number_of_steps', 'number_of_ratings', 'rating_value', 'author',
                         'recipe_time', 'number_of_ingredients', 'number_of_servings', 'image_link']) 

recipe_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   4809 non-null   object
#  1   number_of_steps        4793 non-null   float64
#  2   number_of_ratings      4143 non-null   float64
#  3   rating_value           4143 non-null   float64
#  4   author                 4809 non-null   object
#  5   recipe_time            4748 non-null   object
#  6   number_of_ingredients  4809 non-null   int64
#  7   number_of_servings     4809 non-null   object
#  8   image_link             4809 non-null   object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 338.3+ KB

# %%
recipe_data['rating_value'].value_counts()
# Out:
# 4.0    2646
# 5.0    1346
# 3.0     144
# 2.0       7
# Name: rating_value, dtype: int64

# %%
recipe_data.drop(columns =['image_link'])
recipe_data = recipe_data[recipe_data['number_of_ratings'].notna()]

# %%
with open('start_dates.pickle','rb') as read_file:
    recipe_start_dates = pickle.load(read_file)

len(recipe_start_dates)
# Out:
# 4810

# %%
full_recipe_data = recipe_data.join(recipe_start_dates, rsuffix='_other')
#full_recipe_data.info()
full_recipe_data.sort_values(by = 'number_of_ratings', ascending = False, inplace = True)
full_recipe_data.head(25)
# Out:
#                                                    name  number_of_steps  \
# 2918                                     No-Knead Bread              4.0
# 3860                            Old-Fashioned Beef Stew              3.0
# 847                          Creamy Macaroni and Cheese              3.0
# 713                    Marcella Hazan’s Bolognese Sauce              5.0
# 2403                          Caramelized Shallot Pasta              5.0
# 1154                      Oven-Roasted Chicken Shawarma              3.0
# 844                              Chocolate Chip Cookies              4.0
# 1204                          Roasted Chicken Provençal              4.0
# 2291        Vinegar Chicken With Crushed Olive Dressing              5.0
# 1770          Salted Chocolate Chunk Shortbread Cookies              4.0
# 2777                       Katharine Hepburn’s Brownies              4.0
# 3586                   Jordan Marsh’s Blueberry Muffins              7.0
# 911              Rishia Zimmern’s Chicken With Shallots              5.0
# 4171                                         Dutch Baby              4.0
# 711                       Marcella Hazan’s Tomato Sauce              3.0
# 3434                                  Everyday Pancakes              3.0
# 4631                              Classic Shrimp Scampi              2.0
# 4730                       Takeout-Style Sesame Noodles              3.0
# 1651                         Slow-Cooker Butter Chicken              2.0
# 1134                         Dijon and Cognac Beef Stew              5.0
# 2598                     Perfect Chocolate Chip Cookies              8.0
# 2562                                Ginger-Lime Chicken              4.0
# 1216  Sheet-Pan Chicken With Potatoes, Arugula and G...              5.0
# 2558  Sheet-Pan Baked Feta With Broccolini, Tomatoes...              3.0
# 2376                               Mushroom Bourguignon              4.0
#
#       number_of_ratings  rating_value               author recipe_time  \
# 2918            13705.0           5.0         Mark Bittman     PT1H30M
# 3860            10920.0           5.0        Molly O'Neill     PT2H30M
# 847             10852.0           5.0         Julia Moskin     PT1H40M
# 713             10474.0           5.0   The New York Times        PT4H
# 2403             9910.0           5.0         Alison Roman       PT40M
# 1154             9448.0           5.0           Sam Sifton       PT45M
# 844              8506.0           5.0          David Leite       PT45M
# 1204             8173.0           5.0           Sam Sifton     PT1H15M
# 2291             7576.0           4.0         Alison Roman       PT40M
# 1770             7475.0           5.0         Alison Roman       PT45M
# 2777             7124.0           5.0   The New York Times        PT1H
# 3586             7018.0           5.0        Marian Burros       PT40M
# 911              7006.0           5.0           Sam Sifton     PT1H30M
# 4171             6982.0           5.0   Florence Fabricant       PT40M
# 711              6559.0           5.0   The New York Times        PT1H
# 3434             6439.0           5.0         Mark Bittman       PT20M
# 4631             6373.0           5.0        Melissa Clark       PT15M
# 4730             6312.0           5.0           Sam Sifton       PT10M
# 1651             6176.0           4.0  Jennifer Steinhauer        PT5H
# 1134             6120.0           5.0   Regina Schrambling        PT3H
# 2598             5799.0           4.0   Charlotte Druckman    PT12H30M
# 2562             5694.0           4.0           Ali Slagle       PT15M
# 1216             5617.0           5.0        Melissa Clark        PT1H
# 2558             5404.0           5.0          Yasmin Fahr       PT25M
# 2376             5404.0           4.0        Melissa Clark        PT1H
#
#       number_of_ingredients  \
# 2918                      4
# 3860                     12
# 847                      10
# 713                      14
# 2403                     10
# 1154                     13
# 844                      12
# 1204                     11
# 2291                      8
# 1770                      9
# 2777                      8
# 3586                     10
# 911                      10
# 4171                      7
# 711                       4
# 3434                      7
# 4631                     11
# 4730                     12
# 1651                     15
# 1134                     14
# 2598                      9
# 2562                      5
# 1216                     14
# 2558                     11
# 2376                     18
#
#                                      number_of_servings  \
# 2918                               One 1 1/2-pound loaf
# 3860                                         4 servings
# 847                                     6 to 8 servings
# 713   2 heaping cups, for about 6 servings and 1 1/2...
# 2403                                         4 servings
# 1154                                    4 to 6 servings
# 844                          1 1/2 dozen 5-inch cookies
# 1204                                         4 servings
# 2291                                         6 servings
# 1770                                         24 cookies
# 2777                                        12 brownies
# 3586                                         12 muffins
# 911                                     4 to 6 servings
# 4171                                    3 to 4 servings
# 711                                          4 servings
# 3434                                    4 to 6 servings
# 4631                                         4 servings
# 4730                                         4 servings
# 1651                                    4 to 6 servings
# 1134                                    4 to 6 servings
# 2598                                         14 cookies
# 2562                                         4 servings
# 1216                                         4 servings
# 2558                                         4 servings
# 2376                                    4 to 6 servings
#
#                                              image_link  \
# 2918  https://static01.nyt.com/images/2020/04/16/din...
# 3860  https://static01.nyt.com/images/2021/01/15/din...
# 847   https://static01.nyt.com/images/2019/01/08/din...
# 713   https://static01.nyt.com/images/2015/08/27/din...
# 2403  https://static01.nyt.com/images/2020/01/29/din...
# 1154  https://static01.nyt.com/images/2016/06/06/din...
# 844   https://static01.nyt.com/images/2020/10/15/din...
# 1204  https://static01.nyt.com/images/2017/08/03/din...
# 2291  https://static01.nyt.com/images/2019/12/10/din...
# 1770  https://static01.nyt.com/images/2018/12/12/din...
# 2777  https://static01.nyt.com/images/2018/11/21/din...
# 3586  https://static01.nyt.com/images/2016/05/03/din...
# 911   https://static01.nyt.com/images/2014/03/23/mag...
# 4171  https://static01.nyt.com/images/2018/05/20/din...
# 711   https://static01.nyt.com/images/2015/06/08/din...
# 3434  https://static01.nyt.com/images/2017/03/24/din...
# 4631  https://static01.nyt.com/images/2020/05/03/din...
# 4730  https://static01.nyt.com/images/2017/08/23/din...
# 1651  https://static01.nyt.com/images/2017/07/12/mul...
# 1134  https://static01.nyt.com/images/2018/10/30/din...
# 2598  https://static01.nyt.com/images/2020/10/21/din...
# 2562  https://static01.nyt.com/images/2020/08/03/din...
# 1216  https://static01.nyt.com/images/2015/04/21/din...
# 2558  https://static01.nyt.com/images/2020/12/20/din...
# 2376  https://static01.nyt.com/images/2020/01/01/din...
#
#                                             recipe_link recipe_start_date  \
# 2918  /recipes/11373-chocolate-espresso-twinkies-and...        2015-02-23
# 3860              /recipes/4726-egg-noodles-with-cheese        2014-12-08
# 847         /recipes/1015825-creamy-macaroni-and-cheese        2014-09-28
# 713    /recipes/1015181-marcella-hazans-bolognese-sauce        2015-05-31
# 2403       /recipes/1020828-lemony-shrimp-and-bean-stew        2020-02-02
# 1154     /recipes/1017161-oven-roasted-chicken-shawarma        2015-01-31
# 844             /recipes/1015819-chocolate-chip-cookies        2014-09-28
# 1204         /recipes/1017327-roasted-chicken-provencal        2015-04-04
# 2291   /recipes/1020485-pressure-cooker-bbq-pulled-pork        2019-09-30
# 1770  /recipes/1019146-soy-steamed-fish-with-scallio...        2018-01-14
# 2777    /recipes/10774-pork-with-red-wine-and-coriander        2015-10-05
# 3586       /recipes/2867-mashed-potatoes-with-scallions        2014-12-08
# 911   /recipes/1016135-rishia-zimmerns-chicken-with-...        2014-09-16
# 4171                        /recipes/6646-french-crepes        2014-10-21
# 711       /recipes/1015178-marcella-hazans-tomato-sauce        2014-09-19
# 3434                  /recipes/1886-stuffed-veal-breast        2015-01-03
# 4631         /recipes/910-beef-tongue-with-raisin-sauce        2014-12-02
# 4730  /recipes/9557-mark-bittmans-grilled-eggplant-s...        2015-06-19
# 1651    /recipes/1018802-kuku-paka-chicken-with-coconut        2017-06-21
# 1134        /recipes/1017085-dijon-and-cognac-beef-stew        2014-12-29
# 2598    /recipes/1021433-tunisian-shakshuka-with-shrimp        2020-10-06
# 2562               /recipes/1021289-carne-asada-lorenza        2020-08-12
# 1216  /recipes/1017359-sheet-pan-chicken-with-potato...        2018-04-20
# 2558          /recipes/1021273-white-bean-caprese-salad        2020-08-01
# 2376  /recipes/1020734-skillet-roast-chicken-with-ca...        2020-12-28
#
#                                              name_other
# 2918  Chocolate Espresso Twinkies And Hostess Style ...
# 3860                            Egg Noodles With Cheese
# 847                          Creamy Macaroni And Cheese
# 713                     Marcella Hazans Bolognese Sauce
# 2403                        Lemony Shrimp And Bean Stew
# 1154                      Oven Roasted Chicken Shawarma
# 844                              Chocolate Chip Cookies
# 1204                          Roasted Chicken Provencal
# 2291                    Pressure Cooker Bbq Pulled Pork
# 1770      Soy Steamed Fish With Scallions And Pistachio
# 2777                   Pork With Red Wine And Coriander
# 3586                     Mashed Potatoes With Scallions
# 911               Rishia Zimmerns Chicken With Shallots
# 4171                                      French Crepes
# 711                        Marcella Hazans Tomato Sauce
# 3434                                Stuffed Veal Breast
# 4631                      Beef Tongue With Raisin Sauce
# 4730   Mark Bittmans Grilled Eggplant Salad With Yogurt
# 1651                     Kuku Paka Chicken With Coconut
# 1134                         Dijon And Cognac Beef Stew
# 2598                     Tunisian Shakshuka With Shrimp
# 2562                                Carne Asada Lorenza
# 1216  Sheet Pan Chicken With Potatoes Arugula And Ga...
# 2558                           White Bean Caprese Salad
# 2376    Skillet Roast Chicken With Caramelized Shallots

# %%
from itertools import chain
import itertools
import numpy as np

categories = pd.DataFrame(recipe_dictionary, columns =['name','recipe_categories'])
find_categories = pd.DataFrame(recipe_dictionary, columns =['recipe_categories'])
categories_list = find_categories.values.tolist()
array = np.array(categories_list)
merged = list(itertools.chain.from_iterable(array))
new_list1 = [y for x in merged for y in x.split(',')]
new_list2 = [s.strip() for s in new_list1]
new_list3 = sorted(new_list2)
merged
res = [] 
[res.append(x) for x in new_list3 if x not in res] 
res
test = [(x, new_list3.count(x)) for x in set(new_list3)]
test

def Sort_Tuple(tup):  
    tup.sort(key = lambda x: x[1], reverse = True)  
    return tup  
    # used https://www.geeksforgeeks.org/python-program-to-sort-a-list-of-tuples-by-second-item/

Sort_Tuple(test)
# Out:
# [('main course', 2360),
#  ('dinner', 2230),
#  ('side dish', 940),
#  ('easy', 888),
#  ('dessert', 843),
#  ('quick', 756),
#  ('weekday', 697),
#  ('appetizer', 622),
#  ('lunch', 617),
#  ('pastas', 449),
#  ('soups and stews', 311),
#  ('brunch', 262),
#  ('breakfast', 254),
#  ('seafood', 232),
#  ('project', 214),
#  ('salads and dressings', 206),
#  ('one pot', 196),
#  ('vegetables', 194),
#  ('weeknight', 161),
#  ('snack', 151),
#  ('poultry', 142),
#  ('', 137),
#  ('casseroles', 124),
#  ('breads', 117),
#  ('roasts', 108),
#  ('cakes', 98),
#  ('meat', 90),
#  ('cookies and bars', 90),
#  ('condiments', 81),
#  ('pies and tarts', 75),
#  ('finger foods', 58),
#  ('sauces and gravies', 53),
#  ('ice creams and sorbets', 47),
#  ('grains and rice', 43),
#  ('sandwiches', 42),
#  ('quick breads', 38),
#  ('custards and puddings', 33),
#  ('dips and spreads', 33),
#  ('for one', 32),
#  ('for two', 31),
#  ('burgers', 31),
#  ('noodles', 30),
#  ('barbecues', 29),
#  ('times classics', 27),
#  ('cocktails', 25),
#  ('non-alcoholic drinks', 24),
#  ('beans', 23),
#  ('pastries', 23),
#  ('steaks and chops', 21),
#  ('meatballs', 17),
#  ('candies', 15),
#  ('curries', 13),
#  ('sausages', 12),
#  ('tacos', 12),
#  ('pancakes', 12),
#  ('jellies and preserves', 9),
#  ('jams', 9),
#  ('shakes and smoothies', 8),
#  ('pizza and calzones', 7),
#  ('dumplings', 7),
#  ("editors' pick", 6),
#  ('burritos and nachos', 6),
#  ('skewers and kebabs', 5),
#  ('pickles', 5),
#  ('stuffing and dressing', 5),
#  ('cookbook exclusive', 4),
#  ('crackers and chips', 4),
#  ('parfaits and trifles', 3),
#  ('ice dishes', 2),
#  ('tagine', 1),
#  ('punches', 1)]

# %%
keywords = pd.DataFrame(recipe_dictionary, columns =['name','recipe_keywords'])
find_keywords = pd.DataFrame(recipe_dictionary, columns =['recipe_keywords'])
keywords_list = find_keywords.values.tolist()
array = np.array(keywords_list)
merged = list(itertools.chain.from_iterable(array))
new_list1 = [y for x in merged for y in x.split(',')]
new_list2 = [s.strip() for s in new_list1]
new_list3 = sorted(new_list2)
kw = [] 
[kw.append(x) for x in new_list3 if x not in kw] 
kw
test2 = [(x, new_list3.count(x)) for x in set(new_list3)]
#test2
Sort_Tuple(test2)
# Out:
# [('vegetarian', 1140),
#  ('fall', 681),
#  ('winter', 564),
#  ('summer', 496),
#  ('gluten-free', 442),
#  ('potato', 334),
#  ('nut-free', 331),
#  ('christmas', 324),
#  ('eggs', 320),
#  ('dairy-free', 300),
#  ('pasta', 296),
#  ('thanksgiving', 284),
#  ('spring', 268),
#  ('chicken', 257),
#  ('healthy', 206),
#  ('kosher', 199),
#  ('butter', 199),
#  ('tomato', 198),
#  ('vegan', 197),
#  ('garlic', 181),
#  ('pork', 170),
#  ('chocolate', 166),
#  ('beef', 148),
#  ('heavy cream', 147),
#  ('halal', 147),
#  ('onion', 144),
#  ('flour', 143),
#  ('', 136),
#  ('valentine’s day', 132),
#  ('lemon', 120),
#  ('low cholesterol', 119),
#  ('shrimp', 112),
#  ('seafood', 112),
#  ('ginger', 108),
#  ('fourth of july', 107),
#  ('new year’s day', 107),
#  ('parsley', 103),
#  ('egg', 101),
#  ('mother’s day', 100),
#  ('sugar', 99),
#  ('labor day', 97),
#  ('bittersweet chocolate', 97),
#  ('milk', 96),
#  ('low-fat', 96),
#  ('scallion', 94),
#  ('parmesan', 92),
#  ('high fiber', 92),
#  ('low-sodium', 92),
#  ('ground beef', 90),
#  ('bread', 88),
#  ('easter', 87),
#  ('mushroom', 83),
#  ('tailgate', 80),
#  ('super bowl', 78),
#  ('apple', 75),
#  ('carrot', 73),
#  ('bacon', 71),
#  ('cilantro', 69),
#  ('spinach', 64),
#  ('cocoa powder', 62),
#  ('memorial day', 62),
#  ('leek', 62),
#  ('basil', 60),
#  ('chicken breast', 60),
#  ('shallot', 59),
#  ('father’s day', 59),
#  ('rice', 59),
#  ('white wine', 58),
#  ('rosemary', 54),
#  ('pork chops', 54),
#  ('honey', 53),
#  ('birthday', 52),
#  ('sour cream', 51),
#  ('buttermilk', 51),
#  ('ricotta', 51),
#  ('ground pork', 50),
#  ('hanukkah', 50),
#  ('zucchini', 50),
#  ('all-purpose flour', 49),
#  ('low sugar', 49),
#  ('eggplant', 48),
#  ('thyme', 48),
#  ('salmon', 48),
#  ('olive oil', 48),
#  ('soy sauce', 48),
#  ('cucumber', 47),
#  ('walnut', 47),
#  ('fennel', 47),
#  ('semisweet chocolate', 46),
#  ('cheddar', 46),
#  ('mint', 45),
#  ('coconut milk', 45),
#  ('corn', 45),
#  ('cheese', 45),
#  ('pork tenderloin', 44),
#  ('dill', 44),
#  ('cornmeal', 44),
#  ('pork shoulder', 43),
#  ('passover', 43),
#  ('spices', 43),
#  ('fish sauce', 43),
#  ('cabbage', 42),
#  ('pear', 42),
#  ('orange', 41),
#  ('chicken thigh', 41),
#  ('halloween', 41),
#  ('kale', 41),
#  ('scallops', 41),
#  ('asparagus', 40),
#  ('yogurt', 39),
#  ('jalapeño', 39),
#  ('broccoli', 39),
#  ('lime', 39),
#  ('cumin', 39),
#  ('chickpea', 39),
#  ('feta', 38),
#  ('dried fruit', 37),
#  ('russet potatoes', 37),
#  ('bread crumbs', 37),
#  ('vegetables', 36),
#  ('mozzarella', 36),
#  ('mussels', 36),
#  ('sage', 34),
#  ('vanilla', 34),
#  ('chives', 34),
#  ('yeast', 34),
#  ('olives', 33),
#  ('rosh hashana', 33),
#  ('tomatoes', 33),
#  ('crème fraîche', 33),
#  ('celery', 33),
#  ('red wine', 33),
#  ('spaghetti', 32),
#  ('capers', 32),
#  ('maple syrup', 32),
#  ('peach', 32),
#  ('sweet potato', 31),
#  ('dry red wine', 31),
#  ('gruyère', 31),
#  ('almonds', 30),
#  ('chicken thighs', 30),
#  ('mayonnaise', 30),
#  ('unsweetened chocolate', 29),
#  ('new potatoes', 29),
#  ('pecans', 29),
#  ('goat cheese', 29),
#  ('low-carb', 29),
#  ('whole wheat flour', 29),
#  ('sausage', 29),
#  ('cream cheese', 29),
#  ('lemon juice', 29),
#  ('herbs', 28),
#  ('cinnamon', 28),
#  ('raw', 28),
#  ('cream', 28),
#  ('cherry tomatoes', 28),
#  ('raisins', 28),
#  ('bell pepper', 27),
#  ('clams', 27),
#  ('fruit', 27),
#  ('dijon mustard', 27),
#  ('chicken stock', 27),
#  ('raspberries', 26),
#  ('paprika', 26),
#  ('beef tenderloin', 25),
#  ('lime juice', 25),
#  ('pork loin', 25),
#  ('prune', 25),
#  ('lobster', 25),
#  ('st. patrick’s day', 25),
#  ('avocado', 25),
#  ('blueberries', 25),
#  ('dry white wine', 24),
#  ('ham', 24),
#  ('fish', 24),
#  ('plum', 24),
#  ('banana', 24),
#  ('brown sugar', 24),
#  ('bread flour', 24),
#  ('egg yolks', 23),
#  ('low calorie', 23),
#  ('miso', 23),
#  ('turmeric', 23),
#  ('dark chocolate', 23),
#  ('canned tomatoes', 22),
#  ('lemongrass', 22),
#  ('almond', 22),
#  ('arugula', 22),
#  ('coriander', 22),
#  ('red onion', 22),
#  ('tofu', 22),
#  ('pistachio', 21),
#  ('shiitake', 21),
#  ('oregano', 21),
#  ('hazelnut', 21),
#  ('peas', 21),
#  ('nuts', 21),
#  ('fresh herbs', 21),
#  ('anchovy', 20),
#  ('bourbon', 20),
#  ('red bell pepper', 20),
#  ('berries', 20),
#  ('boneless pork loin', 20),
#  ('rum', 20),
#  ('red pepper flakes', 20),
#  ('white chocolate', 20),
#  ('brandy', 20),
#  ('chicken broth', 19),
#  ('cod', 19),
#  ('swiss chard', 19),
#  ('peanut butter', 19),
#  ('pine nuts', 19),
#  ('saffron', 19),
#  ('egg whites', 19),
#  ('squid', 19),
#  ('mardi gras', 19),
#  ('green beans', 19),
#  ('peanut', 19),
#  ('apricot', 19),
#  ('kentucky derby', 19),
#  ('kwanzaa', 19),
#  ('panko', 19),
#  ('butternut squash', 19),
#  ('cinco de mayo', 18),
#  ('coconut', 18),
#  ('corn tortillas', 18),
#  ('strawberry', 18),
#  ('cognac', 18),
#  ('anchovies', 18),
#  ('bok choy', 18),
#  ('beer', 18),
#  ('tortilla', 17),
#  ('pineapple', 17),
#  ('cocoa', 17),
#  ('rhubarb', 17),
#  ('vanilla bean', 17),
#  ("confectioners' sugar", 17),
#  ('yukon gold potato', 17),
#  ('prosciutto', 17),
#  ('mango', 17),
#  ('beef broth', 17),
#  ('grapefruit', 17),
#  ('sesame seeds', 17),
#  ('extra virgin olive oil', 17),
#  ('beef short ribs', 16),
#  ('cauliflower', 16),
#  ('chicken wings', 16),
#  ('noodles', 16),
#  ('pork belly', 16),
#  ('orange juice', 16),
#  ('red wine vinegar', 16),
#  ('beet', 16),
#  ('penne', 16),
#  ('oats', 16),
#  ('cherries', 16),
#  ('sesame oil', 16),
#  ('anchovy fillets', 16),
#  ('pancetta', 16),
#  ('oyster', 16),
#  ('red potato', 15),
#  ('coconut oil', 15),
#  ('cranberry', 15),
#  ('radicchio', 15),
#  ('mustard', 15),
#  ('dark brown sugar', 15),
#  ('poultry', 15),
#  ('pepper', 15),
#  ('black beans', 15),
#  ('country bread', 15),
#  ('puff pastry', 15),
#  ('watercress', 15),
#  ('horseradish', 15),
#  ('figs', 15),
#  ('greek yogurt', 15),
#  ('white beans', 15),
#  ('vinegar', 14),
#  ('linguine', 14),
#  ('mascarpone', 14),
#  ('chocolate chips', 14),
#  ('lamb', 14),
#  ('chorizo', 14),
#  ('tomato paste', 14),
#  ('boneless pork shoulder', 14),
#  ('lettuce', 14),
#  ('halibut', 14),
#  ('candied fruit', 14),
#  ('greens', 14),
#  ('cannellini beans', 14),
#  ('brussels sprouts', 14),
#  ('broccoli rabe', 14),
#  ('polenta', 14),
#  ('beef stew meat', 13),
#  ('sea scallop', 13),
#  ('pecan', 13),
#  ('pumpkin', 13),
#  ('crab', 13),
#  ('garam masala', 13),
#  ('tahini', 13),
#  ('strawberries', 13),
#  ('fettuccine', 13),
#  ('tomatillo', 13),
#  ('ice cream', 13),
#  ('brioche', 13),
#  ('parsnip', 13),
#  ('active dry yeast', 13),
#  ('parmigiano-reggiano', 13),
#  ('nectarine', 13),
#  ('orzo', 13),
#  ('baguette', 12),
#  ('apple cider', 12),
#  ('sichuan peppercorns', 12),
#  ('fennel seeds', 12),
#  ('beans', 12),
#  ('salmon fillet', 12),
#  ('gold potatoes', 12),
#  ('mint leaves', 12),
#  ('turnip', 12),
#  ('tuna', 12),
#  ('harissa', 12),
#  ('chicken legs', 12),
#  ('wine', 12),
#  ('french bread', 12),
#  ('dried apricots', 12),
#  ('curry powder', 12),
#  ('balsamic vinegar', 12),
#  ('coffee', 12),
#  ('nutmeg', 12),
#  ('lentils', 12),
#  ('cardamom', 11),
#  ('chestnut', 11),
#  ('basmati rice', 11),
#  ('cornbread', 11),
#  ('cake', 11),
#  ('tomato sauce', 11),
#  ('watermelon', 11),
#  ('rigatoni', 11),
#  ('dried cherries', 11),
#  ('pork butt', 11),
#  ('rice vinegar', 11),
#  ('shellfish', 11),
#  ('cremini', 11),
#  ('wild mushrooms', 11),
#  ('quinoa', 10),
#  ('smoked salmon', 10),
#  ('artichoke', 10),
#  ('molasses', 10),
#  ('salt', 10),
#  ('gorgonzola', 10),
#  ('tamarind', 10),
#  ('sauerkraut', 10),
#  ('couscous', 10),
#  ('squash', 10),
#  ('gochujang', 10),
#  ('sweetened condensed milk', 10),
#  ('crab meat', 10),
#  ('tarragon', 10),
#  ('vegetable oil', 10),
#  ('blood orange', 10),
#  ('rice noodles', 10),
#  ('almond flour', 10),
#  ('sherry', 10),
#  ('sourdough', 10),
#  ('green olives', 10),
#  ('turkey', 9),
#  ('ketchup', 9),
#  ('swordfish', 9),
#  ('cake flour', 9),
#  ('unsalted butter', 9),
#  ('flounder', 9),
#  ('espresso', 9),
#  ('veal', 9),
#  ('pesto', 9),
#  ('ghee', 9),
#  ('endive', 9),
#  ('blackberries', 9),
#  ('pecorino', 9),
#  ('waxy potato', 9),
#  ('farfalle', 9),
#  ('daikon', 9),
#  ('tangerine', 9),
#  ('cider vinegar', 9),
#  ('blue cheese', 9),
#  ('baby spinach', 9),
#  ('egg noodles', 9),
#  ('steak', 9),
#  ('chipotles in adobo', 8),
#  ('beef brisket', 8),
#  ('star anise', 8),
#  ('dates', 8),
#  ('portobello', 8),
#  ('sea salt', 8),
#  ('graham cracker', 8),
#  ('peppercorns', 8),
#  ('flank steak', 8),
#  ('smoked paprika', 8),
#  ('sea bass', 8),
#  ('salt pork', 8),
#  ('black pepper', 8),
#  ('pumpkin purée', 8),
#  ('citrus', 8),
#  ('port', 8),
#  ('lard', 8),
#  ('green garlic', 8),
#  ('sardines', 8),
#  ('green pepper', 8),
#  ('brown rice', 8),
#  ('ground veal', 8),
#  ('crushed canned tomatoes', 8),
#  ('chili', 8),
#  ('white vinegar', 8),
#  ('pork sausage', 8),
#  ('root vegetables', 8),
#  ('beets', 8),
#  ('corned beef', 8),
#  ('dried porcini mushrooms', 8),
#  ('dried figs', 8),
#  ('light brown sugar', 8),
#  ('italian sausage', 8),
#  ('gelatin', 8),
#  ('cashew', 8),
#  ('currants', 8),
#  ('red pepper', 8),
#  ('pork rib', 7),
#  ('bay scallops', 7),
#  ('green cabbage', 7),
#  ('jumbo shrimp', 7),
#  ('filet mignon', 7),
#  ('arborio rice', 7),
#  ('ziti', 7),
#  ('dried cranberries', 7),
#  ('calamata olives', 7),
#  ('okra', 7),
#  ('mustard greens', 7),
#  ('chipotle', 7),
#  ('celery root', 7),
#  ('soft-shell crab', 7),
#  ('artichoke hearts', 7),
#  ('mirin', 7),
#  ('chicken liver', 7),
#  ('oxtail', 7),
#  ('scallions', 7),
#  ('bay leaves', 7),
#  ('caviar', 7),
#  ('seaweed', 7),
#  ('rice flour', 7),
#  ('baking potatoes', 7),
#  ('ramps', 7),
#  ('vodka', 7),
#  ('steel-cut oats', 7),
#  ('morels', 7),
#  ('fontina', 7),
#  ('hot sauce', 7),
#  ('sumac', 7),
#  ('whole-wheat flour', 7),
#  ('romaine', 7),
#  ('sirloin', 7),
#  ('beef bones', 7),
#  ('dutch-processed cocoa powder', 7),
#  ('short ribs', 7),
#  ('serrano chili', 7),
#  ('graham cracker crumbs', 7),
#  ('superfine sugar', 7),
#  ('rolled oats', 7),
#  ('barley', 7),
#  ('sugar snap peas', 7),
#  ('curry', 6),
#  ('fish stock', 6),
#  ('bean sprouts', 6),
#  ('poblano pepper', 6),
#  ('brisket', 6),
#  ('sake', 6),
#  ('chilies', 6),
#  ('bulgur', 6),
#  ('worcestershire sauce', 6),
#  ('beef stock', 6),
#  ('radish', 6),
#  ('boneless chicken thighs', 6),
#  ('half and half', 6),
#  ('barbecue sauce', 6),
#  ('serrano pepper', 6),
#  ('kosher salt', 6),
#  ('jasmine rice', 6),
#  ('corn syrup', 6),
#  ('white bread', 6),
#  ('monterey jack cheese', 6),
#  ('farro', 6),
#  ('raisin', 6),
#  ('plum tomato', 6),
#  ('chard', 6),
#  ('caraway seeds', 6),
#  ('kimchi', 6),
#  ('winter squash', 6),
#  ('rutabaga', 6),
#  ('collard greens', 6),
#  ('cardamom pods', 6),
#  ('stale bread', 6),
#  ('bucatini', 6),
#  ('grand marnier', 6),
#  ('pomegranate', 6),
#  ('semisweet chocolate chips', 6),
#  ('orecchiette', 6),
#  ('flour tortillas', 6),
#  ('golden raisins', 6),
#  ('unsweetened cocoa', 6),
#  ('challah bread', 6),
#  ('cilantro leaves', 6),
#  ('vermicelli', 6),
#  ('beef tongue', 6),
#  ('yellow cornmeal', 6),
#  ('cinnamon stick', 6),
#  ('sorrel', 6),
#  ('diwali', 6),
#  ('chili pepper', 6),
#  ('vermouth', 6),
#  ('ground chicken', 6),
#  ('blue crabs', 6),
#  ('mustard seed', 6),
#  ('long-grain rice', 6),
#  ('lemon zest', 6),
#  ('pomegranate seeds', 6),
#  ('sharp cheddar cheese', 6),
#  ('pita', 6),
#  ('beef roast', 6),
#  ('chinese five-spice powder', 6),
#  ('rice wine', 5),
#  ('lean beef', 5),
#  ('salami', 5),
#  ('green chili', 5),
#  ('grapes', 5),
#  ('fava beans', 5),
#  ('preserved lemon', 5),
#  ('marinara sauce', 5),
#  ('phyllo', 5),
#  ('cantaloupe', 5),
#  ('cumin seeds', 5),
#  ('chicken drumsticks', 5),
#  ('orange zest', 5),
#  ('ramadan', 5),
#  ('fish fillets', 5),
#  ('white wine vinegar', 5),
#  ('raspberry', 5),
#  ('ground turkey', 5),
#  ('sun-dried tomato', 5),
#  ('hominy', 5),
#  ('toast', 5),
#  ('blanched almonds', 5),
#  ('kalamata olives', 5),
#  ('littleneck clam', 5),
#  ('kumquats', 5),
#  ('ground lamb', 5),
#  ('black olives', 5),
#  ('rye flour', 5),
#  ('clam juice', 5),
#  ('beef chuck', 5),
#  ('frozen fruit', 5),
#  ('chocolate wafers', 5),
#  ('sourdough starter', 5),
#  ('leeks', 5),
#  ('dark rum', 5),
#  ('meyer lemon', 5),
#  ('high protein', 5),
#  ('oyster sauce', 5),
#  ('pinto beans', 5),
#  ('tortilla chips', 5),
#  ('milk chocolate', 5),
#  ('marjoram', 5),
#  ('monkfish', 5),
#  ('melon', 5),
#  ('ricotta salata', 5),
#  ('condensed milk', 5),
#  ('peppermint extract', 5),
#  ('porcini', 5),
#  ('pumpernickel', 5),
#  ('dark beer', 5),
#  ('ribs', 5),
#  ('jam', 5),
#  ('red snapper', 5),
#  ('chanterelle mushrooms', 5),
#  ('instant coffee', 5),
#  ('galangal', 5),
#  ('snap peas', 5),
#  ('brown lentils', 5),
#  ('pappardelle', 4),
#  ('vegetarian phô broth', 4),
#  ('hoisin sauce', 4),
#  ('grape leaves', 4),
#  ('persimmon', 4),
#  ('whipping cream', 4),
#  ('creamed corn', 4),
#  ('Parmesan', 4),
#  ('matzo', 4),
#  ('curry leaves', 4),
#  ('sambal oelek', 4),
#  ('beef suet', 4),
#  ('challah', 4),
#  ('pork loin chops', 4),
#  ('pozole', 4),
#  ('kielbasa', 4),
#  ('sunflower seeds', 4),
#  ('cloves', 4),
#  ('iceberg lettuce', 4),
#  ('sliced almonds', 4),
#  ('french baguette', 4),
#  ('bosc pear', 4),
#  ('marshmallow', 4),
#  ('rye bread', 4),
#  ('trout', 4),
#  ('plantain', 4),
#  ('broccolini', 4),
#  ('candied ginger', 4),
#  ('ciabatta bread', 4),
#  ('tamari', 4),
#  ('salsa', 4),
#  ('firm white bread', 4),
#  ('spring onions', 4),
#  ('fruit jam', 4),
#  ('caramel', 4),
#  ('pork chop', 4),
#  ('tortellini', 4),
#  ('papaya', 4),
#  ('clementines', 4),
#  ('poblano chili', 4),
#  ('refried beans', 4),
#  ('chinese egg noodles', 4),
#  ('cayenne pepper', 4),
#  ('white fish', 4),
#  ('guinness', 4),
#  ('pimenton', 4),
#  ('ladyfingers', 4),
#  ('summer squash', 4),
#  ('queso fresco', 4),
#  ('fingerling potatoes', 4),
#  ('napa cabbage', 4),
#  ('thai basil', 4),
#  ('chiles de árbol', 4),
#  ('apple cider vinegar', 4),
#  ('soba noodles', 4),
#  ('marsala', 4),
#  ('acorn squash', 4),
#  ('shredded coconut', 4),
#  ('rice wine vinegar', 4),
#  ('chili powder', 4),
#  ('kombu', 4),
#  ('evaporated milk', 4),
#  ('chipotle chilies', 4),
#  ('poppy seed', 4),
#  ('red beets', 4),
#  ('canned plum tomatoes', 4),
#  ('ritz crackers', 4),
#  ('chinese new year', 4),
#  ('chervil', 4),
#  ('italian parsley', 4),
#  ('corn kernels', 4),
#  ('red cabbage', 4),
#  ('sherry vinegar', 4),
#  ('allspice', 4),
#  ('potato chips', 4),
#  ('mackerel', 4),
#  ('lasagna', 3),
#  ('sriracha', 3),
#  ('ruby port', 3),
#  ('black peppercorns', 3),
#  ('string beans', 3),
#  ('stewing beef', 3),
#  ('pea shoots', 3),
#  ('file powder', 3),
#  ('madeira', 3),
#  ('venison', 3),
#  ('pecorino romano', 3),
#  ('sweet paprika', 3),
#  ('red chili', 3),
#  ('pickles', 3),
#  ('hazelnuts', 3),
#  ('cherry peppers', 3),
#  ('focaccia dough', 3),
#  ('chuck steak', 3),
#  ('black truffle', 3),
#  ('pie dough', 3),
#  ('cornstarch', 3),
#  ('apple juice', 3),
#  ('duck', 3),
#  ('bitters', 3),
#  ('za’atar', 3),
#  ('unsweetened coconut milk', 3),
#  ('starfruit', 3),
#  ('peanut oil', 3),
#  ('almond milk', 3),
#  ('peaches', 3),
#  ('almond extract', 3),
#  ('firm tofu', 3),
#  ('wakame seaweed', 3),
#  ('cotija', 3),
#  ('calamari', 3),
#  ('bread dough', 3),
#  ('beef tri-tip', 3),
#  ('ground almonds', 3),
#  ('vegetable shortening', 3),
#  ('mustard powder', 3),
#  ('rose water', 3),
#  ('tart dough', 3),
#  ('peppermint', 3),
#  ('hake', 3),
#  ('green tomato', 3),
#  ('tequila', 3),
#  ('striped bass', 3),
#  ('oatmeal', 3),
#  ('pizza dough', 3),
#  ('dukkah', 3),
#  ('crawfish', 3),
#  ('dried currants', 3),
#  ('dumpling wrappers', 3),
#  ('tabasco sauce', 3),
#  ('tart apples', 3),
#  ('fig', 3),
#  ('matzo meal', 3),
#  ('vegetable stock', 3),
#  ('grape', 3),
#  ('calvados', 3),
#  ('spring roll wrappers', 3),
#  ('pepitas', 3),
#  ('fenugreek', 3),
#  ('yellow bell pepper', 3),
#  ('mortadella', 3),
#  ('halvah', 3),
#  ('tenderloin', 3),
#  ('low-fat milk', 3),
#  ('old-fashioned rolled oats', 3),
#  ('pomegranate juice', 3),
#  ('lemon verbena', 3),
#  ('boneless chuck steak', 3),
#  ('button mushrooms', 3),
#  ('sour cherry', 3),
#  ('stone fruit', 3),
#  ('dandelion greens', 3),
#  ('fusilli', 3),
#  ('rice vermicelli', 3),
#  ('blueberry', 3),
#  ('apricot preserves', 3),
#  ('seeds', 3),
#  ('italian bread', 3),
#  ('applesauce', 3),
#  ('pernod', 3),
#  ('guinness stout', 3),
#  ('demerara sugar', 3),
#  ('white potato', 3),
#  ('coconut flakes', 3),
#  ('sunchoke', 3),
#  ('honeydew', 3),
#  ('chinese dried mushrooms', 3),
#  ('pastry', 3),
#  ('tri-tip steak', 3),
#  ('rye', 3),
#  ('chicken skin', 3),
#  ('habañero', 3),
#  ('vegetable broth', 3),
#  ('vidalia onion', 3),
#  ('poppy seeds', 3),
#  ('lump crab meat', 3),
#  ('pearl onions', 3),
#  ('instant yeast', 3),
#  ('frozen peas', 3),
#  ('spare ribs', 3),
#  ('pink peppercorns', 3),
#  ('oil', 3),
#  ('roast beef', 3),
#  ('doubanjiang', 3),
#  ('espresso coffee powder', 3),
#  ('corn flour', 3),
#  ('chile powder', 3),
#  ('nutella', 3),
#  ('chicken cutlet', 3),
#  ('duck fat', 3),
#  ('capers in salt', 3),
#  ('black coffee', 3),
#  ('brownies', 3),
#  ('spaghettini', 3),
#  ('winter vegetables', 3),
#  ('bouquet garni', 3),
#  ('gin', 3),
#  ('ancho chili', 3),
#  ('malted-milk powder', 3),
#  ('hard cider', 3),
#  ('shell beans', 3),
#  ('medjool dates', 3),
#  ('wonton skins', 3),
#  ('coriander seeds', 3),
#  ('carrots', 3),
#  ('low-fat buttermilk', 3),
#  ('raspberry vinegar', 3),
#  ('swiss cheese', 3),
#  ('passion fruit purée', 2),
#  ('scotch bonnet chile', 2),
#  ('plain yogurt', 2),
#  ('fleur de sel', 2),
#  ('rustic italian bread', 2),
#  ('garbanzo beans', 2),
#  ('sesame paste', 2),
#  ('chickpea flour', 2),
#  ('ham hock', 2),
#  ('millet', 2),
#  ('ground sirloin', 2),
#  ('chia seeds', 2),
#  ('water chestnuts', 2),
#  ('orange marmalade', 2),
#  ('yams', 2),
#  ('mashed potatoes', 2),
#  ('smoked ham', 2),
#  ('beef cheek', 2),
#  ('aged goat cheese', 2),
#  ('salmon roe', 2),
#  ('grapefruit juice', 2),
#  ('oreo cookies', 2),
#  ('white fish fillet', 2),
#  ('black bread', 2),
#  ('white mushrooms', 2),
#  ('pork fatback', 2),
#  ('tangerine juice', 2),
#  ('shiso leaf', 2),
#  ('baby back ribs', 2),
#  ('celery heart', 2),
#  ('truffle', 2),
#  ('canned tuna', 2),
#  ('quince', 2),
#  ('chuck roast', 2),
#  ('asian vegetables', 2),
#  ('smoked sausage', 2),
#  ('jicama', 2),
#  ('crown roast of pork', 2),
#  ('beef chuck roll', 2),
#  ('whole-grain mustard', 2),
#  ('amaretto', 2),
#  ('spaghetti squash', 2),
#  ('dried chili peppers', 2),
#  ('candy', 2),
#  ('macaroni', 2),
#  ('turkey leftovers', 2),
#  ('makrut lime leaf', 2),
#  ('potatoes', 2),
#  ('almond butter', 2),
#  ('boneless pork leg', 2),
#  ('brie', 2),
#  ('sirloin steak', 2),
#  ('beet greens', 2),
#  ('fermented black beans', 2),
#  ('chiles', 2),
#  ('white pepper', 2),
#  ('rye whiskey', 2),
#  ('angel hair pasta', 2),
#  ('turkey stock', 2),
#  ('cavatappi', 2),
#  ('lamb shoulder', 2),
#  ('mixed lettuces', 2),
#  ('slab bacon', 2),
#  ('dry vermouth', 2),
#  ('chorizo sausage', 2),
#  ('ginger root', 2),
#  ('green chile', 2),
#  ('unsweetened cocoa powder', 2),
#  ('onions', 2),
#  ('meat', 2),
#  ('tagliatelle', 2),
#  ('baking soda', 2),
#  ('adobo sauce', 2),
#  ('guajillo chiles', 2),
#  ('top round beef', 2),
#  ('lo mein', 2),
#  ('semisoft cheese', 2),
#  ('rosé', 2),
#  ('crystalized ginger', 2),
#  ('white onion', 2),
#  ('conch', 2),
#  ('spanish chorizo', 2),
#  ('tuna fillet', 2),
#  ('beef fillet', 2),
#  ('shallots', 2),
#  ('mushroom stock', 2),
#  ('lime leaves', 2),
#  ('stilton', 2),
#  ('dried pears', 2),
#  ('dashi', 2),
#  ('salad greens', 2),
#  ('pineapple juice', 2),
#  ('italian pork sausage', 2),
#  ('focaccia', 2),
#  ('elbow macaroni', 2),
#  ('matcha', 2),
#  ('smoked mussels', 2),
#  ('canadian bacon', 2),
#  ('new potato', 2),
#  ('scotch', 2),
#  ('pickling spices', 2),
#  ('buckwheat flour', 2),
#  ('whiskey', 2),
#  ('fatback', 2),
#  ('ale', 2),
#  ('blackberry', 2),
#  ('fregola', 2),
#  ('octopus', 2),
#  ('red chile', 2),
#  ('unflavored gelatin', 2),
#  ('amaretti cookies', 2),
#  ('mixed vegetables', 2),
#  ('hearts of palm', 2),
#  ('roasted red pepper', 2),
#  ('calamansi', 2),
#  ('sponge cake', 2),
#  ('butter lettuce', 2),
#  ('creme de menthe liqueur', 2),
#  ('kelp', 2),
#  ('beef gravy', 2),
#  ('cottage cheese', 2),
#  ('pork cheek', 2),
#  ('red radishes', 2),
#  ('chicken bones', 2),
#  ('fromage blanc', 2),
#  ('masa', 2),
#  ('dark soy sauce', 2),
#  ('provolone', 2),
#  ('ancho chili powder', 2),
#  ('cherry jam', 2),
#  ('pearl onion', 2),
#  ('herbes de provence', 2),
#  ('butter beans', 2),
#  ('whole wheat pastry flour', 2),
#  ('hard-boiled egg', 2),
#  ('bartlett pear', 2),
#  ('tomato puree', 2),
#  ('portuguese chouriço', 2),
#  ('lean pork', 2),
#  ('pork neck bones', 2),
#  ('escarole', 2),
#  ('bass', 2),
#  ('rib roast', 2),
#  ('bacon fat', 2),
#  ('verjuice', 2),
#  ('scrod', 2),
#  ('white chocolate chips', 2),
#  ('hot fudge sauce', 2),
#  ('nori', 2),
#  ('yellow onion', 2),
#  ('cooked potatoes', 2),
#  ('milk chocolate chips', 2),
#  ('adobo seasoning', 2),
#  ('passion fruit', 2),
#  ('stout beer', 2),
#  ('dried morels', 2),
#  ('dried chickpeas', 2),
#  ('english peas', 2),
#  ('bluefish fillet', 2),
#  ('chicken fat', 2),
#  ('ginger beer', 2),
#  ('curry paste', 2),
#  ('navel orange', 2),
#  ('rib eye steak', 2),
#  ('cherrystone clams', 2),
#  ('celeriac', 2),
#  ('grits', 2),
#  ('makrut lime leaves', 2),
#  ('tomato passata', 2),
#  ('instant espresso', 2),
#  ('frisée', 2),
#  ('kiwi', 2),
#  ('taleggio cheese', 2),
#  ('tapioca', 2),
#  ('grapeseed oil', 2),
#  ('pie pastry', 2),
#  ('banana leaf', 2),
#  ('corn on the cob', 2),
#  ('long beans', 2),
#  ('pastry dough', 2),
#  ('chicken livers', 2),
#  ('kohlrabi', 2),
#  ('flaxseed', 2),
#  ('dough', 2),
#  ('honey mustard', 2),
#  ('pudding', 2),
#  ('garlic powder', 2),
#  ('rice krispies', 2),
#  ('apricot jam', 2),
#  ('low-fat yogurt', 2),
#  ('pomegranate molasses', 2),
#  ('whitefish fillet', 2),
#  ('walnut oil', 2),
#  ('eid al-fitr', 2),
#  ('apple butter', 2),
#  ('flounder fillets', 2),
#  ('salmon caviar', 2),
#  ('niçoise olives', 2),
#  ('lox', 2),
#  ('olive juice', 2),
#  ('semolina flour', 2),
#  ('round steak', 2),
#  ('black raisins', 2),
#  ('corn oil', 2),
#  ('tamarind paste', 2),
#  ('00 flour', 2),
#  ('maple sugar', 2),
#  ('pastry flour', 2),
#  ('heirloom tomatoes', 2),
#  ('dark greens', 2),
#  ...]

# %%
categories['main_course'] = categories['recipe_categories'].str.contains('main course')
categories['dinner'] = categories['recipe_categories'].str.contains('dinner')
categories['side_dish'] = categories['recipe_categories'].str.contains('side dish')
categories['easy'] = categories['recipe_categories'].str.contains('easy')
categories['dessert'] = categories['recipe_categories'].str.contains('dessert')
categories['quick'] = categories['recipe_categories'].str.contains('quick')
categories['weekday'] = categories['recipe_categories'].str.contains('weekday')
categories['appetizer'] = categories['recipe_categories'].str.contains('appetizer')
categories['lunch'] = categories['recipe_categories'].str.contains('lunch')
categories.head()
# Out:
#                            name                    recipe_categories  \
# 0      Obstkuchen (Fruit tarts)                              dessert
# 1        Potato-Cheese Pancakes                          easy, quick
# 2  Barbecued Medallions of Pork     dinner, easy, quick, main course
# 3    Scrambled Eggs With Caviar  breakfast, easy, quick, main course
# 4     Troisgros Potatoes Gratin   easy, quick, casseroles, side dish
#
#    main_course  dinner  side_dish   easy  dessert  quick  weekday  appetizer  \
# 0        False   False      False  False     True  False    False      False
# 1        False   False      False   True    False   True    False      False
# 2         True    True      False   True    False   True    False      False
# 3         True   False      False   True    False   True    False      False
# 4        False   False       True   True    False   True    False      False
#
#    lunch
# 0  False
# 1  False
# 2  False
# 3  False
# 4  False

# %%
keywords['vegetarian'] = keywords['recipe_keywords'].str.contains('vegetarian')
keywords['fall'] = keywords['recipe_keywords'].str.contains('fall')
keywords['winter'] = keywords['recipe_keywords'].str.contains('winter')
keywords['summer'] = keywords['recipe_keywords'].str.contains('summer')
keywords.head()
# Out:
#                            name  \
# 0      Obstkuchen (Fruit tarts)
# 1        Potato-Cheese Pancakes
# 2  Barbecued Medallions of Pork
# 3    Scrambled Eggs With Caviar
# 4     Troisgros Potatoes Gratin
#
#                                      recipe_keywords  vegetarian   fall  \
# 0             apple, peach, pear, fall, thanksgiving       False   True
# 1      hanukkah, parmigiano-reggiano, potato, winter       False  False
# 2  chili powder, cider vinegar, pork loin, fourth...       False  False
# 3                                caviar, cream, eggs       False  False
# 4  fall, heavy cream, milk, russet potatoes, vege...        True   True
#
#    winter  summer
# 0   False   False
# 1    True   False
# 2   False    True
# 3   False   False
# 4   False   False

# %%
full_recipe_data_cat = full_recipe_data.join(categories, rsuffix='_cat')
full_recipe_data_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4143 entries, 2 to 4808
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   4143 non-null   object
#  1   number_of_steps        4127 non-null   float64
#  2   number_of_ratings      4143 non-null   float64
#  3   rating_value           4143 non-null   float64
#  4   author                 4143 non-null   object
#  5   recipe_time            4087 non-null   object
#  6   number_of_ingredients  4143 non-null   int64
#  7   number_of_servings     4143 non-null   object
#  8   image_link             4143 non-null   object
#  9   recipe_link            4143 non-null   object
#  10  recipe_start_date      4063 non-null   datetime64[ns]
#  11  name_other             4143 non-null   object
#  12  name_cat               4143 non-null   object
#  13  recipe_categories      4143 non-null   object
#  14  main_course            4143 non-null   bool
#  15  dinner                 4143 non-null   bool
#  16  side_dish              4143 non-null   bool
#  17  easy                   4143 non-null   bool
#  18  dessert                4143 non-null   bool
#  19  quick                  4143 non-null   bool
#  20  weekday                4143 non-null   bool
#  21  appetizer              4143 non-null   bool
#  22  lunch                  4143 non-null   bool
# dtypes: bool(9), datetime64[ns](1), float64(3), int64(1), object(9)
# memory usage: 681.9+ KB

# %%
full_recipe_data_key = full_recipe_data_cat.join(keywords, rsuffix='_key')
full_recipe_data_key.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4143 entries, 2 to 4808
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   4143 non-null   object
#  1   number_of_steps        4127 non-null   float64
#  2   number_of_ratings      4143 non-null   float64
#  3   rating_value           4143 non-null   float64
#  4   author                 4143 non-null   object
#  5   recipe_time            4087 non-null   object
#  6   number_of_ingredients  4143 non-null   int64
#  7   number_of_servings     4143 non-null   object
#  8   image_link             4143 non-null   object
#  9   recipe_link            4143 non-null   object
#  10  recipe_start_date      4063 non-null   datetime64[ns]
#  11  name_other             4143 non-null   object
#  12  name_cat               4143 non-null   object
#  13  recipe_categories      4143 non-null   object
#  14  main_course            4143 non-null   bool
#  15  dinner                 4143 non-null   bool
#  16  side_dish              4143 non-null   bool
#  17  easy                   4143 non-null   bool
#  18  dessert                4143 non-null   bool
#  19  quick                  4143 non-null   bool
#  20  weekday                4143 non-null   bool
#  21  appetizer              4143 non-null   bool
#  22  lunch                  4143 non-null   bool
#  23  name_key               4143 non-null   object
#  24  recipe_keywords        4143 non-null   object
#  25  vegetarian             4143 non-null   bool
#  26  fall                   4143 non-null   bool
#  27  winter                 4143 non-null   bool
#  28  summer                 4143 non-null   bool
# dtypes: bool(13), datetime64[ns](1), float64(3), int64(1), object(11)
# memory usage: 762.8+ KB

# %%
full_recipe_data_key['days_ago'] = (pd.to_datetime("now") - full_recipe_data_key['recipe_start_date']).dt.days
full_recipe_data_key['days_ago']
# Out:
# 2       1955.0
# 5       2148.0
# 6       2261.0
# 7       2090.0
# 8       2312.0
#          ...
# 4802    2059.0
# 4805    1923.0
# 4806    2148.0
# 4807    1922.0
# 4808    1934.0
# Name: days_ago, Length: 4143, dtype: float64

# %%
full_recipe_data_key['recipe_time'].unique()
# Out:
# array(['PT40M', 'PT25M', 'PT39M', 'PT3H', 'PT1H', 'PT1H30M', 'PT30M',
#        'PT10H', 'PT15M', 'PT10M', 'PT6H45M', 'PT20M', 'PT45M', 'PT1H45M',
#        'PT2H', 'P1DT30M', 'PT3H15M', 'PT1H25M', 'PT1H15M', 'PT1H20M',
#        'PT2H30M', 'PT8H30M', None, 'PT50M', 'PT7H', 'PT8M', 'PT21H',
#        'PT5H', 'PT1H35M', 'PT35M', 'PT3H45M', 'PT2H15M', 'PT7M', 'PT5M',
#        'PT3H20M', 'PT1H10M', 'PT1H40M', 'P8D', 'PT15H', 'PT2H45M',
#        'PT10H15M', 'PT6M', 'PT4H', 'PT6H', 'PT12H', 'PT3H30M', 'PT8H',
#        'PT6H30M', 'PT5H15M', 'PT5H30M', 'PT20H30M', 'PT4H30M', 'PT1H5M',
#        'PT4M', 'PT55M', 'PT7H30M', 'PT18M', 'P1DT1H', 'PT6H20M', 'PT11H',
#        'P2DT1H', 'PT4H15M', 'PT1H12M', 'PT2H20M', 'P2D', 'PT1H50M',
#        'PT14H', 'P1DT1H15M', 'P1DT12H', 'PT2M', 'PT2H10M', 'PT16H',
#        'PT3H50M', 'PT13H45M', 'PT5H45M', 'PT10H30M', 'PT4H20M',
#        'PT15H45M', 'PT8H50M', 'P1DT10M', 'P1DT25M', 'PT8H45M', 'P7D',
#        'PT2H40M', 'PT9H45M', 'PT4H45M', 'P2DT45M', 'P1D', 'P1DT3H30M',
#        'PT9H30M', 'PT3H40M', 'PT9H', 'P5DT5M', 'P5DT3H', 'PT8H40M',
#        'PT21H30M', 'P2DT2H', 'P2DT20M', 'PT13H20M', 'PT4H55M', 'P7DT30M',
#        'PT2H35M', 'PT1H55M', 'PT11H15M', 'PT3H35M', 'PT2H50M', 'PT8H15M',
#        'PT6H50M', 'P5DT30M', 'PT8H20M', 'P1DT3H', 'PT12H30M', 'PT13H15M',
#        'P14DT15M', 'P1DT40M', 'PT12H45M', 'P1DT45M', 'PT13H', 'P2DT3H15M',
#        'PT3M', 'PT22M', 'PT1M', 'P3DT6H', 'PT7H45M', 'PT4H10M', 'PT2H25M',
#        'PT19M', 'PT32M', 'PT3H25M', 'PT6H15M', 'PT7H3M', 'P3DT45M',
#        'PT3H10M', 'P1DT22H30M'], dtype=object)

# %%
full_recipe_data_key['recipe_time_new'] = full_recipe_data_key['recipe_time'].str.split('T').str[1]
full_recipe_data_key['recipe_time_hour'] = pd.to_numeric(np.where(full_recipe_data_key['recipe_time_new'].str.contains('H'), full_recipe_data_key['recipe_time_new'].str.split('H').str[0], 0))
full_recipe_data_key['recipe_time_min_w_hour'] = np.where(full_recipe_data_key['recipe_time_new'].str.contains('H'), full_recipe_data_key['recipe_time_new'].str.split('H').str[1], 0)
full_recipe_data_key['recipe_time_min_no_hour'] =  np.where(full_recipe_data_key['recipe_time_new'].str.contains('H') == False, full_recipe_data_key['recipe_time_new'], 0)
full_recipe_data_key['recipe_time_min_w_hour'] = pd.to_numeric(full_recipe_data_key['recipe_time_min_w_hour'].str.strip('M')).fillna(0)
full_recipe_data_key['recipe_time_min_no_hour'] = pd.to_numeric(full_recipe_data_key['recipe_time_min_no_hour'].str.strip('M')).fillna(0)
full_recipe_data_key['recipe_time_in_min'] = (60*full_recipe_data_key['recipe_time_hour']) + full_recipe_data_key['recipe_time_min_w_hour'] + full_recipe_data_key['recipe_time_min_no_hour']

# %%
full_recipe_data_key.drop(columns =['name_cat','name_key','recipe_time_new', 'recipe_time_hour', 'recipe_time_min_w_hour', 'recipe_time_min_no_hour'], inplace = True)
full_recipe_data_key.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4143 entries, 2 to 4808
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   4143 non-null   object
#  1   number_of_steps        4127 non-null   float64
#  2   number_of_ratings      4143 non-null   float64
#  3   rating_value           4143 non-null   float64
#  4   author                 4143 non-null   object
#  5   recipe_time            4087 non-null   object
#  6   number_of_ingredients  4143 non-null   int64
#  7   number_of_servings     4143 non-null   object
#  8   image_link             4143 non-null   object
#  9   recipe_link            4143 non-null   object
#  10  recipe_start_date      4063 non-null   datetime64[ns]
#  11  name_other             4143 non-null   object
#  12  recipe_categories      4143 non-null   object
#  13  main_course            4143 non-null   bool
#  14  dinner                 4143 non-null   bool
#  15  side_dish              4143 non-null   bool
#  16  easy                   4143 non-null   bool
#  17  dessert                4143 non-null   bool
#  18  quick                  4143 non-null   bool
#  19  weekday                4143 non-null   bool
#  20  appetizer              4143 non-null   bool
#  21  lunch                  4143 non-null   bool
#  22  recipe_keywords        4143 non-null   object
#  23  vegetarian             4143 non-null   bool
#  24  fall                   4143 non-null   bool
#  25  winter                 4143 non-null   bool
#  26  summer                 4143 non-null   bool
#  27  days_ago               4063 non-null   float64
#  28  recipe_time_in_min     4137 non-null   float64
# dtypes: bool(13), datetime64[ns](1), float64(5), int64(1), object(9)
# memory usage: 762.8+ KB

# %%
with open('data_set4.pickle', 'wb') as to_write:
        pickle.dump(full_recipe_data_key, to_write)
